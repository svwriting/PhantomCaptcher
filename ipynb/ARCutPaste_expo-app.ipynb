# %%
# !pip3 install npm

# %%
# !mkdir .expo-shared
# !mkdir assets
# !mkdir components

from urllib.request import urlretrieve
url = "https://github.com/cyrildiagne/ar-cutpaste/raw/master/app/.expo-shared/assets.json"
urlretrieve(url, ".expo-shared/assets.json")
url = "https://github.com/cyrildiagne/ar-cutpaste/raw/master/app/components/Base64.tsx"
urlretrieve(url, "components/Base64.tsx")
url = "https://github.com/cyrildiagne/ar-cutpaste/raw/master/app/components/ProgressIndicator.tsx"
urlretrieve(url, "components/ProgressIndicator.tsx")
url = "https://github.com/cyrildiagne/ar-cutpaste/raw/master/app/components/Server.tsx"
urlretrieve(url, "components/Server.tsx")
url = "https://github.com/cyrildiagne/ar-cutpaste/raw/master/app/App.tsx"
urlretrieve(url, "App.tsx")
url = "https://github.com/cyrildiagne/ar-cutpaste/raw/master/app/app.json"
urlretrieve(url, "app.json")
url = "https://github.com/cyrildiagne/ar-cutpaste/raw/master/app/babel.config.js"
urlretrieve(url, "babel.config.js")
url = "https://github.com/cyrildiagne/ar-cutpaste/raw/master/app/package-lock.json"
urlretrieve(url, "package-lock.json")
url = "https://github.com/cyrildiagne/ar-cutpaste/raw/master/app/package.json"
urlretrieve(url, "package.json")
url = "https://github.com/cyrildiagne/ar-cutpaste/raw/master/app/tsconfig.json"
urlretrieve(url, "tsconfig.json")

# %%
if(input("ready?").lower() in ['y','yes']):
  # !npm install
  # !npm start
