# %%
from IPython.display import clear_output

# %% [markdown]
# ================================我是分隔線======================================
# #BASNet

# %%
# %cd drive/MyDrive/TibaMe/'Phantom Captcher'
# !git clone https://github.com/NathanUA/BASNet.git

# %%
# %cd /content/drive/MyDrive/TibaMe/'Phantom Captcher'/BASNet
# !python /content/drive/MyDrive/TibaMe/'Phantom Captcher'/BASNet/basnet_train.py
# %cd /content/

# %%
# %cd /content/drive/MyDrive/TibaMe/'Phantom Captcher'/BASNet
# !python /content/drive/MyDrive/TibaMe/'Phantom Captcher'/BASNet/basnet_test.py
# %cd /content/
