# %%
# !rm -rf

# %%
# !ls -a

# %%
# !git clone https://github.com/bcmi/Image_Harmonization_Datasets.git

# %%
# !pip3 install torch==1.2
# !pip3 install torchvision==0.4
# !pip3 install visdom
# !pip3 install dominate
# !pip3 install Pillow==6.2.2

# %%
# %cd drive/MyDrive/TibaMe/'Phantom Captcher'
# %cd DoveNet

# %%
# !python test.py --dataset_root /content/drive/Shareddrives/幻影捕手/AI班團專_幻影捕手/資料集/Improving_the_Harmony_of_the_Composite_Image/iHarmony4 --name experiment_name_pretrain --model dovenet --dataset_mode iharmony4 --netG s2ad --is_train 0  --norm batch --no_flip --preprocess none --num_test 7404
