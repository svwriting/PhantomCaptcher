# %%
from IPython.display import clear_output
# clear_output()
# !pip3 install boxx
clear_output()

# %%
# %cd /content/drive/MyDrive/TibaMe/'Phantom Captcher'/pcserver_test
# !ls -a
# !pip3 install -r requirements.txt
clear_output()

# %%
# !pip3 install -r requirements.txt
clear_output()

# %%
# !pip install flask-ngrok
clear_output()

# %%
# !python main.py

# %%
# !python main_0test.py
